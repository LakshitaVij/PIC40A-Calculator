# %% [markdown]
# # HW3
#
# ### PageRank
#
# What is the most important website on the internet? Who is the "key player" on a sports team? Which countries are the most central players in the world economy? There is no one correct answer to any of these questions, but there is a most profitable one. [PageRank](https://en.wikipedia.org/wiki/PageRank) is an algorithm for ranking individual elements of complex systems, invited by Sergey Brin and Larry Page. It was the first and most famous algorithm used by the Google Search engine, and it is fair to say that the internet as we know it today would not exist without PageRank.
#
# In this assignment, we will implement PageRank. There are many good ways to implement this algorithm, but in this assignment we will use our newfound skills with object-oriented programming and iterators.
#
# ### How it works
#
# For the purposes of this example, let's assume that we are talking about webpages. PageRank works by allowing a "random surfer" to move around webpages by following links. Each time the surfer lands on a page, it then looks for all the links on that page. It then picks one at random and follows it, thereby arriving at the next page, where the process repeats. Eventually, the surfer will visit all the pages one or more times. Pages that the surfer visits more frequently have higher *PageRank scores*. Because the surfer moves between linked pages, PageRank expresses an intuitive idea: **important pages are linked to other important pages.** [This diagram](https://en.wikipedia.org/wiki/PageRank#/media/File:PageRanks-Example.jpg) from Wikipedia gives a nice illustration. Note that more important webpages (higher PageRank) tend to be connected to other important webpages.
#
# <figure class="image" style="width:50%">
#   <img src="https://upload.wikimedia.org/wikipedia/en/thumb/8/8b/PageRanks-Example.jpg/1920px-PageRanks-Example.jpg
# " alt="A set of 11 circles, with arrows between them. Some of the circles are larger than others, reflecting their high PageRank score. Large circles tend to be linked to other large circles by arrows." width="300px">
#   <figcaption><i>A schematic for PageRank. </i></figcaption>
# </figure>
#
# ### Data
#
# You can complete this assignment using data from one of two sources.
#
# #### Option 1: Hamilton
#
# This data set comes from the hit Broadway musical "Hamilton."
#
# <figure class="image" style="width:25%">
#   <img src="https://m.media-amazon.com/images/M/MV5BNjViNWRjYWEtZTI0NC00N2E3LTk0NGQtMjY4NTM3OGNkZjY0XkEyXkFqcGdeQXVyMjUxMTY3ODM@._V1_.jpg" alt="The logo of the musical Hamilton, showing a silhouette dressed in period custom standing on top of a five-pointed star." width="300px">
#   <figcaption><i>The Hamilton data set</i></figcaption>
# </figure>
#
# The good folks at [The Hamilton Project](http://hamilton.newtfire.org/) analyzed the script for us, obtaining data on **who talks about whom** in each of the show's songs. When character A mentions character B, we'll think of this as a *link* from A to B, suggesting that B might be important.
#
# If you use this data set, listening to the soundtrack while working is strongly recommended.
#
# #### Option 2: Global Airline Network
#
#
# <figure class="image" style="width:50%">
#   <img src="https://openflights.org/demo/openflights-routedb.png" alt="A map of the world, with many curved green lines connecting different points on the map. The points are airports, and the curved green lines are flight routes." width="300px">
#   <figcaption><i>The global airline network</i></figcaption>
# </figure>
#
# Back in the Before Times, lots of people flew on airplanes. This data set includes a "link" from Airport A to Airport B whenever there is a flight from B to A. This data set was collected by the [OpenFlights Project](https://openflights.org/data.html).
#
# ## (A). Define Functions
#
# In this part, all you have to do is hit `shift + enter` on the code block supplied below. This block defines two functions. The first one retrieves the data from the internet and saves it to your local computer, while the second reads in the data, producing a list of tuples. It's not important for you to be familiar with the code in these functions right now -- we'll discuss them soon.

# %%
import urllib
import csv

def retrieve_data(url):
    """
    Retrieve a file from the specified url and save it in a local file 
    called data.csv. The intended values of url are: 
    
    1. https://philchodrow.github.io/PIC16A/homework/HW3-hamilton-data.csv
    2. https://philchodrow.github.io/PIC16A/homework/HW3-flights-data.csv
    """
    
    # grab the data and parse it
    filedata = urllib.request.urlopen(url) 
    to_write = filedata.read()
    
    # write to file
    with open("data.csv", "wb") as f:
        f.write(to_write)
        
def read_data(path):
    """
    read downloaded data from a .csv file, and return a list of tuples. 
    each tuple represents a link between states. 
    """
    with open(path, "r") as f:
        reader = csv.reader(f)
        return [(row[0], row[1]) for row in list(reader)]

# %% [markdown]
# ## (B). Grab the Data
#
# The data live at the following URLs:
#
# - **Hamilton**:  `https://philchodrow.github.io/PIC16A/homework/HW3-hamilton-data.csv`
# - **Airline**:   `https://philchodrow.github.io/PIC16A/homework/HW3-flights-data.csv`
#
# In each data set, each row corresponds to a "link" between objects. In Hamilton, the pairs have format `mentioner, mentioned` while in the airline network the rows have format `destination, origin.`
#
# Pick one of these data sets, and set the variable `url` appropriately by uncommenting one of the two lines below. Then, call `retrieve_data()` and `read_data()`. The `path` argument for `read_data()` should be set to `"data.csv"`.  Create a variable called `data` to hold the return value of `read_data()`.
#
# #### Your solution

# %%
# uncomment the second line if you'd prefer to 
# work with the flights data. 
#url = "https://philchodrow.github.io/PIC16A/homework/HW3-hamilton-data.csv"
url = "https://philchodrow.github.io/PIC16A/homework/HW3-flights-data.csv"

# Call your functions below
retrieve_data(url)
data=read_data("data.csv")

# %% [markdown]
# ## (C). Examine the structure of the data
#
# This would also be a good time to inspect the data to make sure you understand how it is structured. Write a function `describe(n)` that describes the meaning of the `n`th row of the data set you chose. In the Hamilton data set, your function should do the following:
#
# ```python
# describe(5)
#
# # output
# "Element 5 of the Hamilton data set is ('burr', 'betsy'). This means that Burr mentions Betsy in a song."
# ```
#
# In context of the airline flights data, your function should instead do this:
#
# ```python
# describe(5)
#
# # output
# "Element 5 of the flights data set is ('SIN', 'BKK'). This means that there is a flight from BKK to SIN."
# ```
#
# Please attend to capitalization and formatting. While the standard string concatenation operator `+` is completely fine for this task, the fancy `str.format()` function may make your code somewhat simpler. [This page](https://realpython.com/python-formatted-output/) has some useful examples in case you'd like to try this.
#
#
# #### Your Solution

# %%
def describe(n):
    """
    This function takes in the parameter of n, which defines the value at which row of the dataset must be produced
    """
    print ("Element {0} of the flights data set is {1}. This means that there is a flight from {2} to {3}.".format(n, data[n], data[n][0], data[n][1]))
describe(2)
describe(5)
# Out:
# Element 2 of the flights data set is ('ZRH', 'LPA'). This means that there is a flight from ZRH to LPA.
# Element 5 of the flights data set is ('SIN', 'BKK'). This means that there is a flight from SIN to BKK.

# %% [markdown]
# ## (D). Data to Dictionary
#
# Write a function called `data_to_dictionary` that converts the data into a dictionary such that:
#
# 1. There is a single key for each character (in Hamilton) or airport (in flights).
# 2. The value corresponding to each key is a list of the characters/airports to which that key links. The list should contain repeats if there are multiple links.
#
# Here's an example of the desired behavior on a fake data set.
#
# ```python
# data = [("a", "b"),
#         ("a", "b"),
#         ("a", "c"),
#         ("b", "c"),
#         ("b", "a")]
#
# data_to_dictionary(data)
#
# # output
# {"a" : ["b", "b", "c"], "b" : ["a", "c"]}
#
# ```
#
# #### Your Solution

# %%
def data_to_dictionary(data):
    """This function takes in data and creates a dictionary where the keys are the destinations,and values are the connected airports to the destination airport"""
    D = {} #create an empty dictionary 
    for i in data: #for each value in the dataset 
            if(i[0] not in D): #if the destination airport is not in the dictionary, add it to the dictionary
                    D[i[0]] = [i[1]]
            else:
                D[i[0]].append(i[1])  #If it already is, add it to the dictionary in a next position 
                D[i[0]].sort() #Sort the dictionary
    return D 

data_to_dictionary(data)
# Out:
# {'KZN': ['AER'],
#  'LPA': ['ACE',
#   'ACE',
#   'AGP',
#   'AGP',
#   'ALC',
#   'AMS',
#   'ARN',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BHX',
#   'BHX',
#   'BHX',
#   'BRU',
#   'CDG',
#   'CGN',
#   'CGN',
#   'CGN',
#   'CGN',
#   'CMN',
#   'CMN',
#   'CPH',
#   'DUB',
#   'DUB',
#   'DUS',
#   'DUS',
#   'DUS',
#   'DUS',
#   'EDI',
#   'FRA',
#   'FRA',
#   'GVA',
#   'HAM',
#   'HAM',
#   'HAM',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LIS',
#   'LIS',
#   'LTN',
#   'LTN',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MUC',
#   'MUC',
#   'MUC',
#   'MUC',
#   'ORY',
#   'ORY',
#   'OSL',
#   'OSL',
#   'PRG',
#   'STN',
#   'STN',
#   'STR',
#   'STR',
#   'TFS',
#   'TFS',
#   'TXL',
#   'VIE',
#   'VIE',
#   'VIE',
#   'ZRH',
#   'ZRH',
#   'ZRH'],
#  'ZRH': ['ACE',
#   'ACE',
#   'AGP',
#   'ALC',
#   'AMM',
#   'AMS',
#   'AMS',
#   'AMS',
#   'ARN',
#   'ARN',
#   'ATH',
#   'ATL',
#   'AYT',
#   'AYT',
#   'AYT',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BHX',
#   'BKK',
#   'BKK',
#   'BOM',
#   'BOM',
#   'BOS',
#   'BOS',
#   'BRU',
#   'BRU',
#   'CAI',
#   'CAI',
#   'CDG',
#   'CDG',
#   'CGN',
#   'CGN',
#   'CMN',
#   'CPH',
#   'CPH',
#   'CTA',
#   'CTA',
#   'CTA',
#   'DEL',
#   'DEL',
#   'DME',
#   'DOH',
#   'DUB',
#   'DUB',
#   'DUS',
#   'DUS',
#   'DUS',
#   'DXB',
#   'DXB',
#   'DXB',
#   'EWR',
#   'EWR',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FRA',
#   'FRA',
#   'FRA',
#   'GRU',
#   'GVA',
#   'GVA',
#   'GVA',
#   'HAM',
#   'HAM',
#   'HAM',
#   'HEL',
#   'HEL',
#   'HER',
#   'HER',
#   'HKG',
#   'IAD',
#   'IAD',
#   'IST',
#   'IST',
#   'IST',
#   'IST',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JNB',
#   'JNB',
#   'KBP',
#   'KBP',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LED',
#   'LGW',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LPA',
#   'LPA',
#   'LPA',
#   'LTN',
#   'LYS',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAN',
#   'MCT',
#   'MCT',
#   'MIA',
#   'MIA',
#   'MLA',
#   'MLA',
#   'MUC',
#   'MUC',
#   'MXP',
#   'NBO',
#   'NBO',
#   'NBO',
#   'NCE',
#   'NRT',
#   'NRT',
#   'ORD',
#   'ORD',
#   'OSL',
#   'OSL',
#   'OTP',
#   'PEK',
#   'PHL',
#   'PHL',
#   'PMI',
#   'PMI',
#   'PRG',
#   'PRG',
#   'PRG',
#   'PVG',
#   'RIX',
#   'SAW',
#   'SFO',
#   'SFO',
#   'SIN',
#   'SIN',
#   'SIN',
#   'STR',
#   'STR',
#   'SVO',
#   'TFS',
#   'TFS',
#   'TLV',
#   'TLV',
#   'TPA',
#   'TXL',
#   'TXL',
#   'TXL',
#   'TXL',
#   'VCE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'WAW',
#   'WAW',
#   'YUL',
#   'YUL',
#   'YYZ',
#   'YYZ'],
#  'GVA': ['AGP',
#   'AGP',
#   'ALC',
#   'AMM',
#   'AMS',
#   'AMS',
#   'ARN',
#   'ARN',
#   'ARN',
#   'ARN',
#   'ATH',
#   'ATH',
#   'ATH',
#   'AUH',
#   'AUH',
#   'AYT',
#   'BCN',
#   'BCN',
#   'BRU',
#   'BRU',
#   'BRU',
#   'BRU',
#   'CAI',
#   'CAI',
#   'CDG',
#   'CDG',
#   'CMN',
#   'CPH',
#   'CPH',
#   'CPH',
#   'CPH',
#   'CTA',
#   'CTA',
#   'DME',
#   'DOH',
#   'DOH',
#   'DUB',
#   'DUS',
#   'DXB',
#   'DXB',
#   'EDI',
#   'EWR',
#   'EWR',
#   'FAO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FRA',
#   'FRA',
#   'FRA',
#   'FRA',
#   'HAM',
#   'HEL',
#   'HER',
#   'HER',
#   'IAD',
#   'IAD',
#   'IST',
#   'JED',
#   'JFK',
#   'JFK',
#   'KBP',
#   'LED',
#   'LGW',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LTN',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAN',
#   'MLA',
#   'MRS',
#   'MUC',
#   'MUC',
#   'NCE',
#   'NCE',
#   'ORY',
#   'OSL',
#   'OTP',
#   'OTP',
#   'PEK',
#   'PMI',
#   'PMI',
#   'PRG',
#   'RUH',
#   'STR',
#   'SVO',
#   'TFS',
#   'TFS',
#   'TLV',
#   'TLV',
#   'TLV',
#   'VCE',
#   'VIE',
#   'VIE',
#   'WAW',
#   'WAW',
#   'YUL',
#   'YUL',
#   'YUL',
#   'YUL',
#   'ZRH',
#   'ZRH',
#   'ZRH'],
#  'SIN': ['AMS',
#   'AMS',
#   'AUH',
#   'AUH',
#   'AUH',
#   'AUH',
#   'AUH',
#   'AUH',
#   'BCN',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BNE',
#   'BNE',
#   'BNE',
#   'BNE',
#   'BNE',
#   'BNE',
#   'BNE',
#   'BNE',
#   'BNE',
#   'BOM',
#   'BOM',
#   'BOM',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CDG',
#   'CDG',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CKG',
#   'CKG',
#   'CMB',
#   'CMB',
#   'CMB',
#   'CMB',
#   'CMB',
#   'CPH',
#   'CPH',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DEL',
#   'DEL',
#   'DEL',
#   'DEL',
#   'DME',
#   'DME',
#   'DOH',
#   'DXB',
#   'DXB',
#   'DXB',
#   'DXB',
#   'DXB',
#   'FCO',
#   'FOC',
#   'FOC',
#   'FRA',
#   'FRA',
#   'FRA',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HEL',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HND',
#   'HND',
#   'HND',
#   'HND',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'IST',
#   'IST',
#   'IST',
#   'JED',
#   'JNB',
#   'JNB',
#   'JNB',
#   'JNB',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KWE',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'MAA',
#   'MAA',
#   'MAA',
#   'MAA',
#   'MAA',
#   'MAA',
#   'MAA',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MUC',
#   'MUC',
#   'MUC',
#   'MUC',
#   'MXP',
#   'NKG',
#   'NNG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'RUH',
#   'RUH',
#   'SGN',
#   'SGN',
#   'SGN',
#   'SGN',
#   'SGN',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TSN',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'ZRH',
#   'ZRH',
#   'ZRH'],
#  'MNL': ['AUH',
#   'AUH',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CGK',
#   'CGK',
#   'CGK',
#   'DOH',
#   'DOH',
#   'DXB',
#   'DXB',
#   'DXB',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HND',
#   'HND',
#   'HNL',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'JED',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KUL',
#   'KUL',
#   'KUL',
#   'LAX',
#   'LHR',
#   'MEL',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'RUH',
#   'RUH',
#   'SFO',
#   'SGN',
#   'SGN',
#   'SGN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SYD',
#   'SYD',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'XMN',
#   'XMN',
#   'XMN',
#   'YVR'],
#  'TPE': ['AMS',
#   'AMS',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BNE',
#   'BNE',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CDG',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DEL',
#   'DEL',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DXB',
#   'FOC',
#   'FOC',
#   'FRA',
#   'HAK',
#   'HAK',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HNL',
#   'HNL',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'JFK',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SGN',
#   'SGN',
#   'SGN',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SYD',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TSN',
#   'TYN',
#   'URC',
#   'URC',
#   'VIE',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'YVR',
#   'YVR',
#   'YYZ'],
#  'KIX': ['AMS',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'CAN',
#   'CAN',
#   'CDG',
#   'CGK',
#   'CGK',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DOH',
#   'DOH',
#   'DOH',
#   'DXB',
#   'DXB',
#   'FCO',
#   'FOC',
#   'FOC',
#   'FRA',
#   'FRA',
#   'HEL',
#   'HEL',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HND',
#   'HND',
#   'HND',
#   'HNL',
#   'HNL',
#   'HNL',
#   'HNL',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'IST',
#   'IST',
#   'JFK',
#   'KUL',
#   'KUL',
#   'KUL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'NKG',
#   'NKG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SFO',
#   'SFO',
#   'SGN',
#   'SGN',
#   'SHE',
#   'SHE',
#   'SIN',
#   'SIN',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE'],
#  'BKK': ['ADD',
#   'ADD',
#   'AMM',
#   'AMM',
#   'AMS',
#   'AMS',
#   'AMS',
#   'ARN',
#   'ARN',
#   'ARN',
#   'AUH',
#   'AUH',
#   'AUH',
#   'BNE',
#   'BNE',
#   'BOM',
#   'BOM',
#   'BOM',
#   'BOM',
#   'BOM',
#   'BRU',
#   'BRU',
#   'CAI',
#   'CAI',
#   'CAI',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CMB',
#   'CMB',
#   'CMB',
#   'CMB',
#   'CPH',
#   'CPH',
#   'CSX',
#   'CTU',
#   'CTU',
#   'DEL',
#   'DEL',
#   'DEL',
#   'DEL',
#   'DME',
#   'DME',
#   'DME',
#   'DOH',
#   'DXB',
#   'DXB',
#   'DXB',
#   'FCO',
#   'FOC',
#   'FOC',
#   'FRA',
#   'FRA',
#   'HEL',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HND',
#   'HND',
#   'HND',
#   'HND',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'IST',
#   'IST',
#   'JNB',
#   'JNB',
#   'KBP',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KWI',
#   'KWL',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'MAA',
#   'MAA',
#   'MAD',
#   'MCT',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MUC',
#   'MUC',
#   'MXP',
#   'NBO',
#   'NBO',
#   'NBO',
#   'NNG',
#   'NNG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'OSL',
#   'OSL',
#   'OSL',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SGN',
#   'SGN',
#   'SGN',
#   'SGN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SVO',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TLV',
#   'TLV',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'WUH',
#   'XMN',
#   'XMN',
#   'XMN',
#   'ZRH',
#   'ZRH'],
#  'HAK': ['CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TYN',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'HGH': ['AMS',
#   'AMS',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DOH',
#   'FOC',
#   'FOC',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HRB',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SIN',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'URC',
#   'URC',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'HKG': ['ADD',
#   'AMS',
#   'AMS',
#   'AUH',
#   'AUH',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BNE',
#   'BNE',
#   'BNE',
#   'BOM',
#   'BOM',
#   'BOM',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DEL',
#   'DEL',
#   'DEL',
#   'DEL',
#   'DEL',
#   'DLC',
#   'DLC',
#   'DME',
#   'DME',
#   'DME',
#   'DOH',
#   'DOH',
#   'DXB',
#   'DXB',
#   'EWR',
#   'EWR',
#   'EWR',
#   'FCO',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FRA',
#   'FRA',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HEL',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HND',
#   'HND',
#   'HND',
#   'HND',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'IST',
#   'JFK',
#   'JFK',
#   'JNB',
#   'JNB',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'LAX',
#   'LAX',
#   'LHR',
#   'LHR',
#   'LHR',
#   'MAA',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MUC',
#   'MXP',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'RUH',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SGN',
#   'SGN',
#   'SGN',
#   'SGN',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SVO',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYX',
#   'SYX',
#   'SYX',
#   'TAO',
#   'TAO',
#   'TLV',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'YVR',
#   'YVR',
#   'YYZ',
#   'YYZ',
#   'ZRH'],
#  'KUL': ['AMS',
#   'AMS',
#   'AMS',
#   'AUH',
#   'AUH',
#   'AUH',
#   'AUH',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BNE',
#   'BOM',
#   'BOM',
#   'BOM',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CMB',
#   'CMB',
#   'CMB',
#   'CMB',
#   'CTU',
#   'DEL',
#   'DEL',
#   'DEL',
#   'DOH',
#   'DOH',
#   'DXB',
#   'DXB',
#   'DXB',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FRA',
#   'FRA',
#   'FRA',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HND',
#   'ICN',
#   'ICN',
#   'ICN',
#   'IST',
#   'IST',
#   'JED',
#   'JED',
#   'JED',
#   'JED',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KWI',
#   'KWL',
#   'LHR',
#   'LHR',
#   'MAA',
#   'MAA',
#   'MAA',
#   'MAA',
#   'MCT',
#   'MCT',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'NNG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'RUH',
#   'SGN',
#   'SGN',
#   'SGN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SYD',
#   'SYD',
#   'SZX',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'SGN': ['AUH',
#   'AUH',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'CAN',
#   'CAN',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CGK',
#   'DME',
#   'DME',
#   'DOH',
#   'DXB',
#   'FOC',
#   'FRA',
#   'FRA',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HND',
#   'ICN',
#   'ICN',
#   'ICN',
#   'KIX',
#   'KIX',
#   'KUL',
#   'KUL',
#   'KUL',
#   'MEL',
#   'MEL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'NNG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PVG',
#   'PVG',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SVO',
#   'SYD',
#   'SYD',
#   'TPE',
#   'TPE',
#   'TPE'],
#  'MCO': ['ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOG',
#   'BOG',
#   'BOG',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BWI',
#   'BWI',
#   'CLT',
#   'CLT',
#   'CLT',
#   'CLT',
#   'CUN',
#   'CUN',
#   'CUN',
#   'DCA',
#   'DCA',
#   'DCA',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DTW',
#   'DTW',
#   'DUB',
#   'EWR',
#   'EWR',
#   'FLL',
#   'FLL',
#   'FLL',
#   'FRA',
#   'FRA',
#   'GRU',
#   'GRU',
#   'IAD',
#   'IAH',
#   'IAH',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LGA',
#   'LGA',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MDW',
#   'MDW',
#   'MEX',
#   'MEX',
#   'MEX',
#   'MIA',
#   'MIA',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSY',
#   'MSY',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PTY',
#   'PTY',
#   'SAN',
#   'SAN',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SFO',
#   'SJU',
#   'SJU',
#   'SJU',
#   'SJU',
#   'SLC',
#   'STL',
#   'YUL',
#   'YUL',
#   'YYC',
#   'YYZ',
#   'YYZ',
#   'YYZ',
#   'YYZ',
#   'YYZ'],
#  'TPA': ['ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOS',
#   'BWI',
#   'BWI',
#   'CLT',
#   'CLT',
#   'DCA',
#   'DCA',
#   'DCA',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DTW',
#   'DTW',
#   'EWR',
#   'EWR',
#   'FLL',
#   'FLL',
#   'FLL',
#   'FLL',
#   'FLL',
#   'IAD',
#   'IAD',
#   'IAH',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LGA',
#   'LGA',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'MDW',
#   'MDW',
#   'MIA',
#   'MIA',
#   'MSP',
#   'MSY',
#   'MSY',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PTY',
#   'SJU',
#   'SJU',
#   'STL',
#   'STL',
#   'YYZ',
#   'YYZ',
#   'ZRH'],
#  'FLL': ['ARN',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOG',
#   'BOG',
#   'BOG',
#   'BOG',
#   'BOS',
#   'BOS',
#   'BWI',
#   'BWI',
#   'BWI',
#   'CLT',
#   'CLT',
#   'CPH',
#   'CUN',
#   'CUN',
#   'DCA',
#   'DCA',
#   'DCA',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DTW',
#   'DTW',
#   'EWR',
#   'EWR',
#   'IAD',
#   'IAH',
#   'JFK',
#   'JFK',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LGA',
#   'LGA',
#   'LGA',
#   'LIM',
#   'LIM',
#   'MCO',
#   'MCO',
#   'MCO',
#   'MDW',
#   'MSP',
#   'MSY',
#   'MSY',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'OSL',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PTY',
#   'SEA',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SJU',
#   'SJU',
#   'SJU',
#   'SJU',
#   'STL',
#   'STL',
#   'TPA',
#   'TPA',
#   'TPA',
#   'TPA',
#   'TPA',
#   'YUL',
#   'YUL',
#   'YUL',
#   'YYZ',
#   'YYZ',
#   'YYZ',
#   'YYZ'],
#  'CMN': ['AGP',
#   'AGP',
#   'AMS',
#   'AMS',
#   'ARN',
#   'AUH',
#   'AUH',
#   'AUH',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BRU',
#   'BRU',
#   'BRU',
#   'CAI',
#   'CAI',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CPH',
#   'DOH',
#   'DXB',
#   'FCO',
#   'FCO',
#   'FRA',
#   'FRA',
#   'GRU',
#   'GVA',
#   'IST',
#   'IST',
#   'JED',
#   'JED',
#   'JED',
#   'JFK',
#   'LGW',
#   'LGW',
#   'LHR',
#   'LIS',
#   'LIS',
#   'LPA',
#   'LPA',
#   'LYS',
#   'LYS',
#   'LYS',
#   'MAD',
#   'MAD',
#   'MRS',
#   'MUC',
#   'MXP',
#   'MXP',
#   'NCE',
#   'ORY',
#   'RUH',
#   'SAW',
#   'SVO',
#   'SVO',
#   'YUL',
#   'ZRH'],
#  'BCN': ['ACE',
#   'ACE',
#   'ACE',
#   'AGP',
#   'AGP',
#   'AGP',
#   'ALC',
#   'ALC',
#   'AMM',
#   'AMM',
#   'AMS',
#   'AMS',
#   'AMS',
#   'AMS',
#   'AMS',
#   'ARN',
#   'ARN',
#   'ARN',
#   'ARN',
#   'ATH',
#   'ATH',
#   'ATH',
#   'ATH',
#   'BHX',
#   'BHX',
#   'BOG',
#   'BRU',
#   'BRU',
#   'BRU',
#   'BRU',
#   'BRU',
#   'CAI',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CGN',
#   'CMN',
#   'CMN',
#   'CMN',
#   'CMN',
#   'CPH',
#   'CPH',
#   'CPH',
#   'CPH',
#   'CTA',
#   'CTA',
#   'DME',
#   'DME',
#   'DME',
#   'DOH',
#   'DOH',
#   'DOH',
#   'DUB',
#   'DUB',
#   'DUS',
#   'DUS',
#   'DUS',
#   'DUS',
#   'DXB',
#   'EDI',
#   'EDI',
#   'EDI',
#   'EWR',
#   'EWR',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FRA',
#   'FRA',
#   'FRA',
#   'FRA',
#   'GRU',
#   'GVA',
#   'GVA',
#   'HAM',
#   'HAM',
#   'HAM',
#   'HAM',
#   'HEL',
#   'HEL',
#   'HEL',
#   'HEL',
#   'IST',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'KBP',
#   'KBP',
#   'LED',
#   'LED',
#   'LED',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LPA',
#   'LPA',
#   'LPA',
#   'LTN',
#   'LYS',
#   'LYS',
#   'LYS',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MLA',
#   'MLA',
#   'MRS',
#   'MRS',
#   'MUC',
#   'MUC',
#   'MUC',
#   'MXP',
#   'MXP',
#   'MXP',
#   'MXP',
#   'NCE',
#   'NCE',
#   'NCE',
#   'ORY',
#   'ORY',
#   'OSL',
#   'OSL',
#   'OSL',
#   'OSL',
#   'OTP',
#   'OTP',
#   'OTP',
#   'OTP',
#   'OTP',
#   'PHL',
#   'PHL',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PRG',
#   'PRG',
#   'PRG',
#   'PRG',
#   'PRG',
#   'RIX',
#   'SAW',
#   'SIN',
#   'STN',
#   'STR',
#   'STR',
#   'STR',
#   'SVO',
#   'SVO',
#   'TFS',
#   'TFS',
#   'TFS',
#   'TLV',
#   'TLV',
#   'TLV',
#   'TLV',
#   'TXL',
#   'TXL',
#   'TXL',
#   'TXL',
#   'VCE',
#   'VCE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'WAW',
#   'WAW',
#   'WAW',
#   'WAW',
#   'WAW',
#   'YUL',
#   'YYZ',
#   'YYZ',
#   'ZRH',
#   'ZRH',
#   'ZRH'],
#  'BRU': ['AGP',
#   'AGP',
#   'AGP',
#   'AGP',
#   'AGP',
#   'ALC',
#   'ALC',
#   'ALC',
#   'ALC',
#   'AMS',
#   'ARN',
#   'ATH',
#   'ATH',
#   'ATL',
#   'ATL',
#   'ATL',
#   'AUH',
#   'AUH',
#   'AUH',
#   'AYT',
#   'AYT',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BHX',
#   'BHX',
#   'BKK',
#   'BKK',
#   'BOM',
#   'BOM',
#   'CAI',
#   'CAI',
#   'CDG',
#   'CDG',
#   'CMN',
#   'CMN',
#   'CMN',
#   'CPH',
#   'CPH',
#   'CPH',
#   'CPH',
#   'CTA',
#   'CTA',
#   'DEL',
#   'DEL',
#   'DEL',
#   'DME',
#   'DOH',
#   'DUB',
#   'EDI',
#   'EDI',
#   'EWR',
#   'EWR',
#   'EWR',
#   'EWR',
#   'EWR',
#   'FAO',
#   'FAO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FRA',
#   'FRA',
#   'FRA',
#   'GVA',
#   'GVA',
#   'GVA',
#   'GVA',
#   'HAM',
#   'HAM',
#   'HEL',
#   'HER',
#   'HER',
#   'HER',
#   'IAD',
#   'IAD',
#   'IAD',
#   'IST',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'KBP',
#   'KBP',
#   'LGW',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LPA',
#   'LYS',
#   'LYS',
#   'LYS',
#   'LYS',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAN',
#   'MLA',
#   'MLA',
#   'MRS',
#   'MUC',
#   'MUC',
#   'MXP',
#   'MXP',
#   'MXP',
#   'MXP',
#   'NBO',
#   'NBO',
#   'NBO',
#   'NBO',
#   'NCE',
#   'NCE',
#   'ORD',
#   'ORD',
#   'OSL',
#   'OSL',
#   'OTP',
#   'OTP',
#   'PEK',
#   'PEK',
#   'PHL',
#   'PHL',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PRG',
#   'PRG',
#   'PRG',
#   'PRG',
#   'RIX',
#   'RIX',
#   'SAW',
#   'STR',
#   'SVO',
#   'TFS',
#   'TLV',
#   'TLV',
#   'TXL',
#   'TXL',
#   'TXL',
#   'VCE',
#   'VCE',
#   'VCE',
#   'VIE',
#   'VIE',
#   'WAW',
#   'YUL',
#   'YUL',
#   'YUL',
#   'YUL',
#   'YYZ',
#   'YYZ',
#   'ZRH',
#   'ZRH'],
#  'LGW': ['ACE',
#   'ACE',
#   'ACE',
#   'ACE',
#   'ACE',
#   'ACE',
#   'ACE',
#   'ACE',
#   'ACE',
#   'AGP',
#   'AGP',
#   'AGP',
#   'AGP',
#   'AGP',
#   'AGP',
#   'ALC',
#   'ALC',
#   'ALC',
#   'ALC',
#   'ALC',
#   'ALC',
#   'AMS',
#   'AMS',
#   'ARN',
#   'ATH',
#   'AYT',
#   'AYT',
#   'AYT',
#   'AYT',
#   'AYT',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BRU',
#   'CDG',
#   'CGN',
#   'CMN',
#   'CMN',
#   'CPH',
#   'CPH',
#   'CTA',
#   'CTA',
#   'CTA',
#   'CTA',
#   'CTA',
#   'CTA',
#   'CUN',
#   'CUN',
#   'CUN',
#   'CUN',
#   'CUN',
#   'CUN',
#   'DME',
#   'DME',
#   'DUB',
#   'DUB',
#   'DUS',
#   'DXB',
#   'DXB',
#   'EDI',
#   'EDI',
#   'FAO',
#   'FAO',
#   'FAO',
#   'FAO',
#   'FAO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'GVA',
#   'HAM',
#   'HEL',
#   'HER',
#   'HER',
#   'HER',
#   'IST',
#   'JED',
#   'KBP',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LPA',
#   'LPA',
#   'LPA',
#   'LPA',
#   'LPA',
#   'LYS',
#   'MAD',
#   'MAD',
#   'MCO',
#   'MCO',
#   'MCO',
#   'MCO',
#   'MCO',
#   'MCO',
#   'MCO',
#   'MLA',
#   'MLA',
#   'MLA',
#   'MLA',
#   'MRS',
#   'MUC',
#   'MXP',
#   'NCE',
#   'NCE',
#   'NCE',
#   'NCE',
#   'OSL',
#   'OTP',
#   'PEK',
#   'PEK',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PRG',
#   'RIX',
#   'SAW',
#   'TFS',
#   'TFS',
#   'TFS',
#   'TFS',
#   'TFS',
#   'TFS',
#   'TFS',
#   'TFS',
#   'TLV',
#   'TPA',
#   'TPA',
#   'TPA',
#   'TPA',
#   'VCE',
#   'VCE',
#   'VCE',
#   'VCE',
#   'VIE',
#   'YUL',
#   'YVR',
#   'YYC',
#   'YYZ',
#   'ZRH'],
#  'LYS': ['AGP',
#   'AGP',
#   'AMS',
#   'AMS',
#   'ATH',
#   'ATH',
#   'ATH',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BHX',
#   'BHX',
#   'BRU',
#   'BRU',
#   'BRU',
#   'BRU',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CMN',
#   'CMN',
#   'CMN',
#   'CTA',
#   'CTA',
#   'DUB',
#   'DUS',
#   'DXB',
#   'EDI',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FRA',
#   'FRA',
#   'FRA',
#   'HER',
#   'IST',
#   'LGW',
#   'LHR',
#   'LHR',
#   'LIS',
#   'LIS',
#   'MAD',
#   'MAD',
#   'MLA',
#   'MLA',
#   'MRS',
#   'MUC',
#   'MXP',
#   'MXP',
#   'MXP',
#   'NCE',
#   'NCE',
#   'ORY',
#   'PMI',
#   'PMI',
#   'PRG',
#   'PRG',
#   'STN',
#   'VCE',
#   'VCE',
#   'VCE',
#   'VIE',
#   'VIE',
#   'YUL',
#   'ZRH'],
#  'SAW': ['AMS',
#   'AMS',
#   'AMS',
#   'ARN',
#   'ATH',
#   'AYT',
#   'AYT',
#   'AYT',
#   'BCN',
#   'BRU',
#   'CDG',
#   'CGN',
#   'CGN',
#   'CGN',
#   'CMN',
#   'CPH',
#   'DME',
#   'DOH',
#   'DUS',
#   'DUS',
#   'DUS',
#   'DXB',
#   'DXB',
#   'FCO',
#   'FRA',
#   'FRA',
#   'HAM',
#   'JED',
#   'KBP',
#   'KBP',
#   'KWI',
#   'KWI',
#   'KWI',
#   'KWI',
#   'LGW',
#   'MAD',
#   'MLA',
#   'MLA',
#   'MRS',
#   'MUC',
#   'MUC',
#   'MUC',
#   'MXP',
#   'ORY',
#   'ORY',
#   'OTP',
#   'RIX',
#   'RUH',
#   'STN',
#   'STR',
#   'STR',
#   'STR',
#   'TLV',
#   'TLV',
#   'TXL',
#   'VIE',
#   'VIE',
#   'ZRH'],
#  'CKG': ['BKK',
#   'BKK',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'DLC',
#   'DOH',
#   'FOC',
#   'FOC',
#   'FOC',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HEL',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'ICN',
#   'ICN',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SIN',
#   'SIN',
#   'SYD',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'CTU': ['AMS',
#   'AMS',
#   'AUH',
#   'AUH',
#   'AUH',
#   'BKK',
#   'BKK',
#   'BOM',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'DOH',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FRA',
#   'FRA',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'LHR',
#   'MEL',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'HRB': ['CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CSX',
#   'CTU',
#   'CTU',
#   'DLC',
#   'DLC',
#   'DLC',
#   'FOC',
#   'FOC',
#   'HGH',
#   'HGH',
#   'HGH',
#   'ICN',
#   'ICN',
#   'KIX',
#   'NKG',
#   'NKG',
#   'NKG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY'],
#  'KMG': ['BKK',
#   'BKK',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CMB',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DLC',
#   'DXB',
#   'FOC',
#   'FOC',
#   'FOC',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'ICN',
#   'ICN',
#   'KUL',
#   'KUL',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SIN',
#   'SIN',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'URC': ['CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'HGH',
#   'IST',
#   'KWE',
#   'NKG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SVO',
#   'SVO',
#   'SZX',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY'],
#  'CAN': ['ADD',
#   'ADD',
#   'ADD',
#   'AMS',
#   'AMS',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BNE',
#   'CAI',
#   'CAI',
#   'CDG',
#   'CDG',
#   'CGK',
#   'CGK',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DEL',
#   'DLC',
#   'DOH',
#   'DXB',
#   'DXB',
#   'FOC',
#   'FOC',
#   'FOC',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HRB',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'IST',
#   'IST',
#   'JED',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'LAX',
#   'LAX',
#   'LHR',
#   'MEL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'NBO',
#   'NBO',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'RUH',
#   'SGN',
#   'SGN',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SVO',
#   'SVO',
#   'SYD',
#   'SYX',
#   'SYX',
#   'SYX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'URC',
#   'URC',
#   'URC',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'YVR'],
#  'CGO': ['BKK',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'CSX': ['BKK',
#   'CAN',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DLC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SIN',
#   'SIN',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'URC',
#   'URC',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'DLC': ['CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CSX',
#   'FOC',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HRB',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KMG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN'],
#  'NKG': ['CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FRA',
#   'FRA',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HRB',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SIN',
#   'SYD',
#   'SYD',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TYN',
#   'TYN',
#   'TYN',
#   'URC',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'NNG': ['BKK',
#   'BKK',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'NKG',
#   'NKG',
#   'NKG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SGN',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SIN',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TPE',
#   'TPE',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'PEK': ['ADD',
#   'ADD',
#   'AMS',
#   'AMS',
#   'ARN',
#   'ARN',
#   'AUH',
#   'AUH',
#   'AUH',
#   'AUH',
#   'AUH',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BRU',
#   'BRU',
#   'CAI',
#   'CAI',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CGK',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CMB',
#   'CPH',
#   'CPH',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DEL',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DOH',
#   'DTW',
#   'DTW',
#   'DTW',
#   'DUS',
#   'DUS',
#   'DXB',
#   'DXB',
#   'EWR',
#   'EWR',
#   'FCO',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FRA',
#   'FRA',
#   'GVA',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HEL',
#   'HEL',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HND',
#   'HND',
#   'HND',
#   'HND',
#   'HNL',
#   'HNL',
#   'HNL',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'IAD',
#   'IAD',
#   'IAH',
#   'IAH',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'IST',
#   'IST',
#   'JFK',
#   'JFK',
#   'JFK',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KUL',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LED',
#   'LED',
#   'LGW',
#   'LGW',
#   'LHR',
#   'LHR',
#   'LHR',
#   'MAD',
#   'MAD',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MUC',
#   'MUC',
#   'MXP',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SGN',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SIN',
#   'SIN',
#   'SVO',
#   'SVO',
#   'SVO',
#   'SVO',
#   'SYD',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TLV',
#   'TLV',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TXL',
#   'TXL',
#   'TYN',
#   'TYN',
#   'TYN',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'VIE',
#   'VIE',
#   'WAW',
#   'WAW',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'YVR',
#   'YVR',
#   'YYZ',
#   'YYZ',
#   'YYZ',
#   'ZRH'],
#  'PVG': ['ADD',
#   'AMS',
#   'AMS',
#   'AMS',
#   'AUH',
#   'AUH',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CGK',
#   'CGK',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CMB',
#   'CPH',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DEL',
#   'DEL',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DOH',
#   'DTW',
#   'DTW',
#   'DTW',
#   'DXB',
#   'EWR',
#   'EWR',
#   'FCO',
#   'FCO',
#   'FOC',
#   'FOC',
#   'FRA',
#   'FRA',
#   'FRA',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HEL',
#   'HEL',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HNL',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'IST',
#   'IST',
#   'JFK',
#   'JFK',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KUL',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'KWL',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MNL',
#   'MUC',
#   'MUC',
#   'MXP',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SGN',
#   'SGN',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SVO',
#   'SVO',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'URC',
#   'URC',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'YVR',
#   'YVR',
#   'YVR',
#   'YYZ',
#   'YYZ',
#   'ZRH'],
#  'SYD': ['AUH',
#   'AUH',
#   'AUH',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BKK',
#   'BNE',
#   'BNE',
#   'BNE',
#   'BNE',
#   'BNE',
#   'CAN',
#   'CGK',
#   'CGK',
#   'CGK',
#   'CKG',
#   'DEL',
#   'DXB',
#   'DXB',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HNL',
#   'HNL',
#   'HNL',
#   'HNL',
#   'HNL',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'JNB',
#   'JNB',
#   'KUL',
#   'KUL',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MNL',
#   'MNL',
#   'NKG',
#   'NKG',
#   'NRT',
#   'NRT',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SFO',
#   'SFO',
#   'SGN',
#   'SGN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'TPE',
#   'YVR'],
#  'SYX': ['CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DME',
#   'FOC',
#   'FOC',
#   'FOC',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'SZX': ['BKK',
#   'BKK',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DLC',
#   'DLC',
#   'DLC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HAK',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HRB',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KUL',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'KWL',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NKG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'NNG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SYX',
#   'SYX',
#   'SYX',
#   'SYX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TSN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'TYN',
#   'URC',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'TNA': ['BKK',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'FOC',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KWE',
#   'KWE',
#   'KWL',
#   'KWL',
#   'PEK',
#   'PEK',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TPE',
#   'TPE',
#   'TYN',
#   'TYN',
#   'URC',
#   'URC',
#   'URC',
#   'URC',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'TSN': ['CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CGO',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'FOC',
#   'HAK',
#   'HAK',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'HRB',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KWL',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SIN',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TPE',
#   'TYN',
#   'URC',
#   'WUH',
#   'WUH',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN',
#   'XMN'],
#  'TYN': ['CAN',
#   'CAN',
#   'CAN',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CSX',
#   'CSX',
#   'CSX',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'FOC',
#   'HAK',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HGH',
#   'HKG',
#   'HKG',
#   'HRB',
#   'HRB',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KMG',
#   'KWE',
#   'KWL',
#   'KWL',
#   'NKG',
#   'NKG',
#   'NKG',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PVG',
#   'PVG',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHA',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SHE',
#   'SYX',
#   'SYX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'SZX',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TAO',
#   'TNA',
#   'TNA',
#   'TPE',
#   'TSN',
#   'URC',
#   'URC',
#   'URC',
#   'WUH',
#   'WUH',
#   'XIY',
#   'XIY',
#   'XMN',
#   'XMN'],
#  'WUH': ['BKK',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CDG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CKG',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'CTU',
#   'DLC',
#   'DLC',
#   'DLC',
#   'DLC',
#   'FOC',
#   'FOC',
#   'FOC',
# ...
#   'MIA',
#   'MIA',
#   'MSP',
#   'MSP',
#   'MSY',
#   'MUC',
#   'MUC',
#   'NRT',
#   'NRT',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PDX',
#   'PDX',
#   'PDX',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PTY',
#   'PTY',
#   'SAN',
#   'SAN',
#   'SAN',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SJU',
#   'SLC',
#   'STL',
#   'TPA',
#   'YUL',
#   'YUL',
#   'YYZ',
#   'YYZ',
#   'ZRH',
#   'ZRH'],
#  'BWI': ['ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOS',
#   'BOS',
#   'BOS',
#   'CLT',
#   'CLT',
#   'CLT',
#   'CLT',
#   'CUN',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DTW',
#   'DTW',
#   'DTW',
#   'EWR',
#   'FLL',
#   'FLL',
#   'FLL',
#   'IAH',
#   'JFK',
#   'JFK',
#   'JFK',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'MCO',
#   'MCO',
#   'MDW',
#   'MDW',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MSP',
#   'MSP',
#   'MSY',
#   'MSY',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PHL',
#   'PHL',
#   'PHX',
#   'PHX',
#   'PHX',
#   'SAN',
#   'SAN',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SJU',
#   'SLC',
#   'SLC',
#   'SLC',
#   'STL',
#   'STL',
#   'TPA',
#   'TPA',
#   'YYZ'],
#  'DEN': ['ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BWI',
#   'BWI',
#   'BWI',
#   'CLT',
#   'CLT',
#   'CUN',
#   'CUN',
#   'CUN',
#   'DCA',
#   'DCA',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DTW',
#   'DTW',
#   'DTW',
#   'DTW',
#   'DTW',
#   'EWR',
#   'EWR',
#   'FLL',
#   'FLL',
#   'FLL',
#   'FLL',
#   'FRA',
#   'FRA',
#   'HNL',
#   'IAD',
#   'IAD',
#   'IAD',
#   'IAH',
#   'IAH',
#   'IAH',
#   'JFK',
#   'JFK',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LGA',
#   'LGA',
#   'LGA',
#   'LGA',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'MCO',
#   'MCO',
#   'MCO',
#   'MCO',
#   'MDW',
#   'MDW',
#   'MDW',
#   'MEX',
#   'MEX',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSY',
#   'MSY',
#   'MSY',
#   'MSY',
#   'MSY',
#   'NRT',
#   'NRT',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PDX',
#   'PDX',
#   'PDX',
#   'PDX',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PHX',
#   'SAN',
#   'SAN',
#   'SAN',
#   'SAN',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SLC',
#   'SLC',
#   'SLC',
#   'SLC',
#   'STL',
#   'STL',
#   'STL',
#   'STL',
#   'TPA',
#   'TPA',
#   'TPA',
#   'YUL',
#   'YUL',
#   'YVR',
#   'YVR',
#   'YYC',
#   'YYC',
#   'YYZ',
#   'YYZ'],
#  'GRU': ['AMS',
#   'ATL',
#   'AUH',
#   'BCN',
#   'BOG',
#   'BOG',
#   'BOG',
#   'CDG',
#   'CDG',
#   'CLT',
#   'CLT',
#   'CMN',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DOH',
#   'DTW',
#   'DTW',
#   'DXB',
#   'EWR',
#   'FCO',
#   'FRA',
#   'FRA',
#   'IAD',
#   'IAH',
#   'IST',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JNB',
#   'JNB',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LHR',
#   'LHR',
#   'LIM',
#   'LIM',
#   'LIM',
#   'LIM',
#   'LIS',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MCO',
#   'MCO',
#   'MEX',
#   'MEX',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MUC',
#   'MUC',
#   'MXP',
#   'ORD',
#   'PTY',
#   'YYZ',
#   'YYZ',
#   'ZRH'],
#  'IAH': ['AMS',
#   'AMS',
#   'AMS',
#   'AMS',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOG',
#   'BOG',
#   'BOS',
#   'BWI',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CLT',
#   'CLT',
#   'CLT',
#   'CUN',
#   'CUN',
#   'DCA',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DME',
#   'DME',
#   'DOH',
#   'DOH',
#   'DOH',
#   'DTW',
#   'DTW',
#   'DTW',
#   'DXB',
#   'DXB',
#   'EWR',
#   'FLL',
#   'FRA',
#   'FRA',
#   'GRU',
#   'HNL',
#   'IAD',
#   'ICN',
#   'IST',
#   'IST',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LGA',
#   'LGA',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LIM',
#   'MCO',
#   'MCO',
#   'MEX',
#   'MEX',
#   'MEX',
#   'MEX',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSY',
#   'MSY',
#   'MSY',
#   'MSY',
#   'MUC',
#   'NRT',
#   'NRT',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PDX',
#   'PEK',
#   'PEK',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PTY',
#   'PTY',
#   'SAN',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SJU',
#   'SLC',
#   'SLC',
#   'STL',
#   'TPA',
#   'YUL',
#   'YUL',
#   'YVR',
#   'YYC',
#   'YYC',
#   'YYZ',
#   'YYZ'],
#  'SFO': ['AMS',
#   'AMS',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOS',
#   'BOS',
#   'BOS',
#   'BWI',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CLT',
#   'CLT',
#   'CPH',
#   'CUN',
#   'CUN',
#   'DCA',
#   'DCA',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DTW',
#   'DUB',
#   'DXB',
#   'DXB',
#   'EWR',
#   'EWR',
#   'FLL',
#   'FLL',
#   'FLL',
#   'FLL',
#   'FRA',
#   'FRA',
#   'FRA',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HND',
#   'HND',
#   'HNL',
#   'HNL',
#   'HNL',
#   'IAD',
#   'IAD',
#   'IAH',
#   'IAH',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'KIX',
#   'KIX',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'MCO',
#   'MCO',
#   'MDW',
#   'MDW',
#   'MEX',
#   'MEX',
#   'MEX',
#   'MEX',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MNL',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSY',
#   'MUC',
#   'MUC',
#   'NRT',
#   'NRT',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PDX',
#   'PDX',
#   'PDX',
#   'PDX',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PVG',
#   'PVG',
#   'PVG',
#   'PVG',
#   'SAN',
#   'SAN',
#   'SAN',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SLC',
#   'SLC',
#   'STL',
#   'SYD',
#   'SYD',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'TPE',
#   'YUL',
#   'YUL',
#   'YVR',
#   'YVR',
#   'YVR',
#   'YYC',
#   'YYC',
#   'YYC',
#   'YYZ',
#   'YYZ',
#   'ZRH',
#   'ZRH'],
#  'SJU': ['ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOG',
#   'BOS',
#   'BWI',
#   'BWI',
#   'CLT',
#   'CLT',
#   'DCA',
#   'DFW',
#   'DFW',
#   'DTW',
#   'EWR',
#   'EWR',
#   'FLL',
#   'FLL',
#   'FLL',
#   'FLL',
#   'FRA',
#   'IAD',
#   'IAH',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'JFK',
#   'MCO',
#   'MCO',
#   'MCO',
#   'MCO',
#   'MIA',
#   'MIA',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PHL',
#   'PHL',
#   'PTY',
#   'TPA',
#   'TPA',
#   'TPA',
#   'YYZ'],
#  'SLC': ['ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOS',
#   'BWI',
#   'BWI',
#   'BWI',
#   'CDG',
#   'CDG',
#   'CLT',
#   'CLT',
#   'CLT',
#   'CUN',
#   'CUN',
#   'DCA',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DTW',
#   'EWR',
#   'HNL',
#   'IAH',
#   'IAH',
#   'JFK',
#   'JFK',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'MCO',
#   'MDW',
#   'MDW',
#   'MSP',
#   'MSY',
#   'MSY',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PDX',
#   'PDX',
#   'PDX',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PHX',
#   'SAN',
#   'SAN',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SFO',
#   'STL',
#   'YVR',
#   'YYC'],
#  'STL': ['ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOS',
#   'BWI',
#   'BWI',
#   'CLT',
#   'CLT',
#   'CUN',
#   'DCA',
#   'DCA',
#   'DCA',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DFW',
#   'DFW',
#   'DTW',
#   'DTW',
#   'EWR',
#   'EWR',
#   'FLL',
#   'IAD',
#   'IAH',
#   'JFK',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LGA',
#   'LGA',
#   'LGA',
#   'LGA',
#   'MCO',
#   'MCO',
#   'MDW',
#   'MDW',
#   'MIA',
#   'MIA',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSY',
#   'MSY',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PHL',
#   'PHL',
#   'PHL',
#   'PHX',
#   'PHX',
#   'PHX',
#   'SAN',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SLC',
#   'TPA',
#   'TPA',
#   'YYZ',
#   'YYZ'],
#  'BNE': ['BKK',
#   'BKK',
#   'CAN',
#   'DFW',
#   'DFW',
#   'DXB',
#   'DXB',
#   'HKG',
#   'HKG',
#   'HKG',
#   'HNL',
#   'ICN',
#   'KUL',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'MEL',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SIN',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'TPE',
#   'TPE'],
#  'HNL': ['ATL',
#   'BNE',
#   'DEN',
#   'DFW',
#   'DFW',
#   'EWR',
#   'HND',
#   'HND',
#   'HND',
#   'HND',
#   'HND',
#   'IAD',
#   'IAH',
#   'ICN',
#   'ICN',
#   'ICN',
#   'ICN',
#   'JFK',
#   'KIX',
#   'KIX',
#   'KIX',
#   'KIX',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'MEL',
#   'MEL',
#   'MNL',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'NRT',
#   'ORD',
#   'PDX',
#   'PDX',
#   'PEK',
#   'PEK',
#   'PEK',
#   'PHX',
#   'PHX',
#   'PHX',
#   'PVG',
#   'SAN',
#   'SAN',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SLC',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'SYD',
#   'TPE',
#   'TPE',
#   'YVR',
#   'YVR',
#   'YVR'],
#  'LIM': ['AMS',
#   'AMS',
#   'ATL',
#   'BOG',
#   'BOG',
#   'CDG',
#   'CDG',
#   'CUN',
#   'DFW',
#   'DFW',
#   'DFW',
#   'EWR',
#   'FLL',
#   'FLL',
#   'GRU',
#   'GRU',
#   'GRU',
#   'GRU',
#   'IAH',
#   'JFK',
#   'JFK',
#   'JFK',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MEX',
#   'MEX',
#   'MEX',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MIA',
#   'PTY',
#   'YYZ'],
#  'PTY': ['AMS',
#   'AMS',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOG',
#   'BOG',
#   'BOS',
#   'BOS',
#   'CDG',
#   'CUN',
#   'CUN',
#   'DFW',
#   'DFW',
#   'EWR',
#   'EWR',
#   'FLL',
#   'GRU',
#   'IAD',
#   'IAD',
#   'IAH',
#   'IAH',
#   'JFK',
#   'JFK',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LIM',
#   'MAD',
#   'MCO',
#   'MCO',
#   'MEX',
#   'MEX',
#   'MIA',
#   'MIA',
#   'MIA',
#   'MIA',
#   'ORD',
#   'ORD',
#   'SJU',
#   'TPA',
#   'YYZ'],
#  'YYC': ['AMS',
#   'AMS',
#   'AMS',
#   'CUN',
#   'CUN',
#   'CUN',
#   'DEN',
#   'DEN',
#   'DFW',
#   'DFW',
#   'DFW',
#   'DFW',
#   'EWR',
#   'FRA',
#   'FRA',
#   'FRA',
#   'IAH',
#   'IAH',
#   'JFK',
#   'JFK',
#   'JFK',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LAX',
#   'LGW',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LHR',
#   'MAN',
#   'MCO',
#   'MSP',
#   'NRT',
#   'NRT',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'ORD',
#   'PDX',
#   'PDX',
#   'PHX',
#   'PHX',
#   'PHX',
#   'SAN',
#   'SAN',
#   'SEA',
#   'SFO',
#   'SFO',
#   'SFO',
#   'SLC',
#   'YUL',
#   'YUL',
#   'YVR',
#   'YVR',
#   'YVR',
#   'YYZ',
#   'YYZ'],
#  'ORY': ['AGP',
#   'AGP',
#   'AGP',
#   'ALC',
#   'ALC',
#   'ARN',
#   'ATH',
#   'ATH',
#   'AYT',
#   'BCN',
#   'BCN',
#   'CMN',
#   'CPH',
#   'CTA',
#   'EWR',
#   'EWR',
#   'EWR',
#   'FAO',
#   'FAO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'GVA',
#   'HEL',
#   'HER',
#   'JFK',
#   'JFK',
#   'JFK',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LPA',
#   'LPA',
#   'LYS',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MLA',
#   'MLA',
#   'MLA',
#   'MRS',
#   'MRS',
#   'NCE',
#   'NCE',
#   'OSL',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PRG',
#   'SAW',
#   'SAW',
#   'TFS',
#   'TLV',
#   'TXL',
#   'VCE',
#   'VCE',
#   'YUL'],
#  'AMM': ['AMS',
#   'ATH',
#   'AUH',
#   'AUH',
#   'AUH',
#   'BCN',
#   'BCN',
#   'BKK',
#   'BKK',
#   'BOM',
#   'CAI',
#   'CAI',
#   'CAI',
#   'CDG',
#   'CDG',
#   'DEL',
#   'DME',
#   'DME',
#   'DOH',
#   'DOH',
#   'DXB',
#   'DXB',
#   'DXB',
#   'DXB',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FRA',
#   'FRA',
#   'FRA',
#   'GVA',
#   'IST',
#   'IST',
#   'JED',
#   'JED',
#   'JED',
#   'JED',
#   'JFK',
#   'JFK',
#   'JFK',
#   'KBP',
#   'KWI',
#   'KWI',
#   'KWI',
#   'LHR',
#   'LHR',
#   'MAD',
#   'MAD',
#   'MCT',
#   'MCT',
#   'MUC',
#   'MUC',
#   'ORD',
#   'ORD',
#   'ORD',
#   'OTP',
#   'OTP',
#   'RUH',
#   'RUH',
#   'RUH',
#   'TLV',
#   'TLV',
#   'TXL',
#   'TXL',
#   'VIE',
#   'VIE',
#   'VIE',
#   'YUL',
#   'YUL',
#   'YUL',
#   'ZRH'],
#  'CPH': ['AGP',
#   'AGP',
#   'AGP',
#   'AGP',
#   'ALC',
#   'ALC',
#   'ALC',
#   'AMS',
#   'AMS',
#   'AMS',
#   'AMS',
#   'AMS',
#   'AMS',
#   'ARN',
#   'ARN',
#   'ARN',
#   'ATH',
#   'ATH',
#   'AYT',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BHX',
#   'BKK',
#   'BKK',
#   'BRU',
#   'BRU',
#   'BRU',
#   'BRU',
#   'CAI',
#   'CAI',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CDG',
#   'CTA',
#   'DOH',
#   'DUB',
#   'DUB',
#   'DUB',
#   'DUS',
#   'DUS',
#   'DUS',
#   'DUS',
#   'DXB',
#   'DXB',
#   'EDI',
#   'EDI',
#   'EWR',
#   'FAO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FLL',
#   'FRA',
#   'FRA',
#   'FRA',
#   'FRA',
#   'GVA',
#   'GVA',
#   'GVA',
#   'GVA',
#   'HAM',
#   'HAM',
#   'HEL',
#   'HEL',
#   'HEL',
#   'IAD',
#   'IST',
#   'IST',
#   'JFK',
#   'LAX',
#   'LED',
#   'LGW',
#   'LGW',
#   'LHR',
#   'LHR',
#   'LHR',
#   'LIS',
#   'LIS',
#   'LIS',
#   'LPA',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MLA',
#   'MUC',
#   'MUC',
#   'MXP',
#   'MXP',
#   'NCE',
#   'NCE',
#   'NRT',
#   'ORD',
#   'ORY',
#   'OSL',
#   'OSL',
#   'OSL',
#   'OTP',
#   'PEK',
#   'PEK',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PRG',
#   'PRG',
#   'PRG',
#   'PRG',
#   'PVG',
#   'RIX',
#   'RIX',
#   'RIX',
#   'SAW',
#   'SFO',
#   'SIN',
#   'SIN',
#   'STN',
#   'STR',
#   'SVO',
#   'SVO',
#   'TLV',
#   'TLV',
#   'TXL',
#   'TXL',
#   'TXL',
#   'TXL',
#   'TXL',
#   'TXL',
#   'VCE',
#   'VCE',
#   'VCE',
#   'VCE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'WAW',
#   'WAW',
#   'WAW',
#   'YYZ',
#   'YYZ',
#   'YYZ',
#   'ZRH',
#   'ZRH'],
#  'ACE': ['AMS',
#   'BCN',
#   'BCN',
#   'BCN',
#   'BHX',
#   'BHX',
#   'BHX',
#   'BHX',
#   'BHX',
#   'BHX',
#   'BRU',
#   'CGN',
#   'DUB',
#   'DUB',
#   'DUS',
#   'DUS',
#   'EDI',
#   'FRA',
#   'FRA',
#   'HAM',
#   'HAM',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LPA',
#   'LPA',
#   'LPA',
#   'LTN',
#   'LTN',
#   'LTN',
#   'MAD',
#   'MAD',
#   'MAD',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MUC',
#   'MUC',
#   'STN',
#   'STN',
#   'STN',
#   'STR',
#   'STR',
#   'TXL',
#   'VIE',
#   'VIE',
#   'ZRH',
#   'ZRH'],
#  'ALC': ['AMS',
#   'AMS',
#   'AMS',
#   'ARN',
#   'ARN',
#   'BCN',
#   'BCN',
#   'BHX',
#   'BHX',
#   'BHX',
#   'BHX',
#   'BRU',
#   'BRU',
#   'BRU',
#   'BRU',
#   'CGN',
#   'CPH',
#   'CPH',
#   'CPH',
#   'DME',
#   'DME',
#   'DME',
#   'DME',
#   'DUB',
#   'DUB',
#   'DUS',
#   'EDI',
#   'EDI',
#   'EDI',
#   'FCO',
#   'FCO',
#   'FRA',
#   'GVA',
#   'HAM',
#   'HAM',
#   'HEL',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LPA',
#   'LTN',
#   'LTN',
#   'MAD',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MUC',
#   'MUC',
#   'ORY',
#   'ORY',
#   'OSL',
#   'OSL',
#   'PMI',
#   'PMI',
#   'PMI',
#   'STN',
#   'STR',
#   'TFS',
#   'TXL',
#   'ZRH'],
#  'MLA': ['AMS',
#   'AMS',
#   'ARN',
#   'ATH',
#   'BCN',
#   'BCN',
#   'BHX',
#   'BHX',
#   'BRU',
#   'BRU',
#   'CDG',
#   'CDG',
#   'CPH',
#   'CTA',
#   'CTA',
#   'CTA',
#   'DME',
#   'DUB',
#   'DUS',
#   'DUS',
#   'DXB',
#   'EDI',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FCO',
#   'FRA',
#   'FRA',
#   'GVA',
#   'HAM',
#   'IST',
#   'IST',
#   'LED',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LGW',
#   'LHR',
#   'LTN',
#   'LYS',
#   'LYS',
#   'MAD',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MAN',
#   'MRS',
#   'MRS',
#   'MUC',
#   'MUC',
#   'ORY',
#   'ORY',
#   'ORY',
#   'OSL',
#   'PRG',
#   'PRG',
#   'RIX',
#   'SAW',
#   'SAW',
#   'STN',
#   'SVO',
#   'SVO',
#   'TXL',
#   'VIE',
#   'VIE',
#   'VIE',
#   'VIE',
#   'ZRH',
#   'ZRH'],
#  'ADD': ['ARN',
#   'ARN',
#   'BKK',
#   'BKK',
#   'BOM',
#   'BOM',
#   'CAI',
#   'CAI',
#   'CAN',
#   'CAN',
#   'CAN',
#   'CDG',
#   'DEL',
#   'DEL',
#   'DOH',
#   'DXB',
#   'DXB',
#   'DXB',
#   'FCO',
#   'FRA',
#   'FRA',
#   'HKG',
#   'IAD',
#   'IST',
#   'JED',
#   'JED',
#   'JED',
#   'JED',
#   'JED',
#   'JED',
#   'JNB',
#   'JNB',
#   'KWI',
#   'KWI',
#   'KWI',
#   'LHR',
#   'MCT',
#   'MCT',
#   'NBO',
#   'NBO',
#   'NBO',
#   'NBO',
#   'PEK',
#   'PEK',
#   'PVG',
#   'RUH',
#   'RUH',
#   'TLV',
#   'YYZ'],
#  'MDW': ['ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'ATL',
#   'BOS',
#   'BOS',
#   'BWI',
#   'BWI',
#   'CLT',
#   'CLT',
#   'CUN',
#   'DEN',
#   'DEN',
#   'DEN',
#   'DTW',
#   'DTW',
#   'DTW',
#   'EWR',
#   'EWR',
#   'FLL',
#   'IAD',
#   'IAD',
#   'LAS',
#   'LAS',
#   'LAX',
#   'LAX',
#   'LGA',
#   'LGA',
#   'MCO',
#   'MCO',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSP',
#   'MSY',
#   'MSY',
#   'PDX',
#   'PDX',
#   'PHL',
#   'PHL',
#   'PHX',
#   'SAN',
#   'SEA',
#   'SEA',
#   'SFO',
#   'SFO',
#   'SLC',
#   'SLC',
#   'STL',
#   'STL',
#   'TPA',
#   'TPA'],
#  'KBP': ['AMM',
#   'AMS',
#   'AMS',
#   'ATH',
#   'BCN',
#   'BCN',
#   'BKK',
#   'BRU',
#   'BRU',
#   'CDG',
#   'CDG',
#   'DME',
#   'DME',
#   'DXB',
#   'DXB',
#   'FCO',
#   'FCO',
#   'FRA',
#   'FRA',
#   'GVA',
#   'HEL',
#   'HER',
#   'IST',
#   'IST',
#   'IST',
#   'IST',
#   'JFK',
#   'LED',
#   'LED',
#   'LED',
#   'LED',
#   'LGW',
#   'LHR',
#   'LIS',
#   'LIS',
#   'MAD',
#   'MAD',
#   'MUC',
#   'MUC',
#   'MXP',
#   'NCE',
#   'OSL',
#   'PRG',
#   'PRG',
#   'PRG',
#   'RIX',
#   'RIX',
#   'SAW',
#   'SAW',
#   'SVO',
#   'SVO',
#   'TFS',
#   'TLV',
#   'TLV',
#   'TXL',
#   'VIE',
#   'VIE',
#   'WAW',
#   'WAW',
#   'ZRH',
#   'ZRH'],
#  'LTN': ['ACE',
#   'ACE',
#   'ACE',
#   'AGP',
#   'AGP',
#   'AGP',
#   'ALC',
#   'ALC',
#   'AMS',
#   'AYT',
#   'AYT',
#   'BCN',
#   'CDG',
#   'CTA',
#   'DUB',
#   'EDI',
#   'FAO',
#   'FAO',
#   'FAO',
#   'FCO',
#   'GVA',
#   'HAM',
#   'HER',
#   'IST',
#   'LIS',
#   'LPA',
#   'LPA',
#   'MAD',
#   'MLA',
#   'MXP',
#   'NCE',
#   'OTP',
#   'PMI',
#   'PMI',
#   'PMI',
#   'PRG',
#   'RIX',
#   'TFS',
#   'TFS',
#   'TFS',
#   'TLV',
#   'TLV',
#   'VCE',
#   'WAW',
#   'ZRH']}

# %% [markdown]
# ## (E). Define a PR_DiGraph class
#
# A **directed graph**, or DiGraph, is just a set of arrows ("edges") between objects ("nodes"). It is a natural way to represent data that represents one-way relationships, such as links from one webpage to another or mentions of one character by another. We already saw a directed graph above when we introduced the idea of PageRank. Here's a paired-down example.
#
# <figure class="image" style="width:50%">
#   <img src="https://computersciencewiki.org/images/c/c6/Directed_graph.png" alt="Six circles, representing nodes, labeled A through F. There are directed arrows between certain pairs of nodes." width="300px">
#   <figcaption><i>Example of a directed graph. </i></figcaption>
# </figure>
#
# Implement a `PR_DiGraph` class with a custom `__init__()` method and a `linked_by()` method. The `__init__()` method should accept two arguments: `data` and `iteration_limit`. The `__init__()` method should then construct an instance variable `self.link_dict` which is simply the output of `data_to_dictionary` applied to the argument `data`. `__init__()` should also construct an instance variable `self.iteration_limit`, which simply takes the value of `iteration_limit` supplied to `__init__()`. Don't worry about that one for now.
#
# Then, define a method `self.linked_by(x)` which, when called, returns the value `self.link_dict[x]`.
#
# Finally, add an `__iter__` method, which returns an object of class `PR_Iterator`. We will define this class in the next part.
#
# Example session (using Hamilton):
#
# ```python
# D = PR_DiGraph(data, iteration_limit = 10000)
# D.linked_by('peggy')
#
# # output
# ['peggy', 'schuylerSis']
# ```
#
# #### Your Solution

# %%
class PR_DiGraph:
    """This class takes in the parameters of data, iteration limit, and x, then calls the dictionary of that defines the linked function of connected airports that takes in value x, and finally, returns the iterator"""
    def __init__(self, data, iteration_limit):
        """This function has parameters of data and iteration value limit, and then it defines variable that links to the data dictionary,and the iteration variable
as the iteration value limit"""
        self.link_dict = data_to_dictionary(data)
        self.iteration_limit = iteration_limit
        
    def linked_by(self, x):
        """This function takes in the value of x and returns the value of link to dictionary indexing x"""
        return self.link_dict[x]
        
    def __iter__(self):
        """Returns the value of the class PR_Iterator"""
        return PR_Iterator(self)

# %% [markdown]
# ## (F). Implement PR_Iterator
#
# Define a `PR_Iterator` class with a custom `__next__()` method.
#
# The `__init__` method of this class should create instance variables to store the `PR_DiGraph` object from which it was constructed; a counter `i`, starting at 0, to log the number of steps taken, and a `current_state` variable whose value is one of the keys of the `link_dict` of the `Pr_DiGraph`. You can choose its initial value arbitrarily; in my solution code I chose `self.current_state = "hamilton"`.
#
# We are going to use iteration to implement the PageRank algorithm. This  means we are going to imagine a surfer who is following the links in our data set. **Implement the following two methods:**
#
# 1. `follow_link()`.
#     1. Pick a random new character mentioned by the current character, or new airport served by the current airport. Let's call this `next_state`.
#     2. If `next_state != current_state`, set `current_state` to `next_state`.
#     3. Otherwise (if `next_state == current_state`), teleport (see below).
#     4. You might run into `KeyError`s, in which case you should again teleport (use a `try-except` block).
# 2. `teleport()`.
#     1. Set the current state to a new state (key of the link dict) completely at random.
#
# *Hint*: use `random.choice` from the `random` module to choose elements of lists.
#
# Finally, **implement** `__next__()`. `__next__()` should do `follow_link()` with 85% probability, and do `teleport()` with 15% probability. You should also define a custom `StopIteration` condition to ensure that only as many steps are taken as the `iteration_limit` supplied to the `PR_DiGraph` initializer.
#
# 1. To do something with 85% probability, use the following:
#
# ```
# if random.random() < 0.85:
#     # do the thing
# else:
#     # do the other thing
# ```
#
#
# #### Example Usage
#
# After you define your class, run the following code and show that it works. Note: your precise sequence may be different from mine.
#
# ```python
# D = PR_DiGraph(data, iteration_limit = 5)
# for char in D:
#     print(char)
#
# following link : current state = burr
# following link : current state = washington
# following link : current state = burr
# following link : current state = hamilton
# teleporting    : current state = washington
# ```
#
# I have added printed messages here for you to more clearly see what should be happening, but it is not necessary for you to do this. It is sufficient for your output to look like:
#
# ```python
# D = PR_DiGraph(data, iteration_limit = 5)
# for char in D:
#     print(char)
#
# burr
# washington
# burr
# hamilton
# washington
# ```
#
# #### Your Solution

# %%
import random
class PR_Iterator:
    def __init__(self,graph):
        """Takes in the parameter of graph, an instance variable that stores the value of PR_DiGraph, initializes self.i as a counter,
        with the initial value being 0 for the steps taken, and sets the initial value of the current state to an arbitrary place, which in this I have chosen as BKK
        """
        self.graph=graph
        self.i=0
        self.current_state="BKK"
    def follow_link(self):
        """
        Chooses a new airport at random that is served by a current airport, jumping from one airport to the next.
        If it lands at the same airport, then the function teleports
        """
        try:
            next_state = random.choice(list(self.graph.link_dict[self.current_state]))
            if next_state!=self.current_state:
                self.current_state=next_state
            else:
                self.teleport
        except KeyError:
                self.teleport
    def teleport(self):
        """
        Change the current state to a randomly chosen airport 
        """
        self.current_state=random.choice(list(self.graph.link_dict.keys()))
    def __next__(self):
        """
        Execute follow_link with 85% probability, and self_teleport ith 15% probability.
        Along with that, this function makes sure that the iteration limit is followed, and once its met, returns the current state.
        """
        if self.i == self.graph.iteration_limit: 
            raise StopIteration
        self.i+=1
        if random.random()<0.85:
            self.follow_link()
        else:
            self.teleport()
        return self.current_state

# %%
# run the below
D = PR_DiGraph(data, iteration_limit = 5)
for char in D:
    print(char)
# Out:
# ZRH
# DEL
# HRB
# TNA
# SHA

# %% [markdown]
# ## (G). Compute PageRank
#
# Finally, we are ready to compute the PageRank in our data set. Initialize a `PR_DiGraph` with a large iteration limit (say, 1,000,000). Use a `for`-loop to allow your surfer to randomly move through the data set. The number of times that the surfer visits state `x` is the PageRank score of `x`.
#
# Create a `dict` which logs how many times a given state appears when iterating through the `PR_Digraph`. So, this dictionary holds the PageRank score of each state.
#
# #### Your Solution

# %%
A=PR_DiGraph(data, iteration_limit=1000000)
D={} #creating an empty dictionary to count the D keys 
for i in A:
    try:
        D[i]+=1 #if the value of D[i] already exists as a key, increment it by 1 
    except KeyError: #if the value doesnt exist, and its a keyerror because the key doesnt exist, initialize it to 1
        D[i]=1
print(D)
# Out:
# {'SIN': 10254, 'HKG': 10927, 'MEL': 3345, 'AUH': 7808, 'MNL': 4125, 'ICN': 10368, 'BKK': 9771, 'XMN': 7656, 'NRT': 9441, 'CPH': 7777, 'AGP': 5706, 'BHX': 4038, 'ALC': 3971, 'LTN': 3144, 'EDI': 4111, 'LIS': 6878, 'MAD': 9841, 'VIE': 8940, 'TFS': 4678, 'MUC': 10958, 'LPA': 4506, 'MAN': 8316, 'BCN': 10625, 'STR': 4357, 'DUB': 6091, 'PRG': 6436, 'CDG': 14374, 'IST': 7347, 'URC': 3657, 'CKG': 7459, 'KBP': 3747, 'BRU': 8708, 'TPE': 8377, 'HNL': 4104, 'JNB': 3265, 'XIY': 8278, 'KWL': 4608, 'DXB': 9139, 'SVO': 5155, 'DEN': 7194, 'YUL': 6004, 'DME': 4971, 'HER': 4203, 'ZRH': 8602, 'DTW': 6262, 'EWR': 7934, 'PVG': 11255, 'SZX': 6705, 'CAN': 9022, 'HGH': 8447, 'CTU': 8640, 'NKG': 6091, 'WAW': 4444, 'LED': 3981, 'IAH': 6041, 'DOH': 6296, 'BOM': 5010, 'KWI': 3681, 'RUH': 4037, 'ADD': 2964, 'JED': 5034, 'NNG': 4746, 'YVR': 4758, 'SHE': 4504, 'SHA': 6064, 'KMG': 7722, 'WUH': 6269, 'FRA': 14217, 'KUL': 6496, 'CMB': 3623, 'MAA': 2952, 'HND': 3429, 'SGN': 3416, 'CTA': 4502, 'LGW': 8187, 'FCO': 10722, 'YYZ': 9049, 'SAN': 4626, 'LAX': 13126, 'LAS': 6507, 'BOS': 6558, 'BOG': 3090, 'PDX': 3875, 'DFW': 9174, 'TPA': 4161, 'FLL': 4965, 'SFO': 8547, 'MEX': 5024, 'PEK': 12448, 'SEA': 6545, 'JFK': 14786, 'PMI': 6267, 'MCO': 6233, 'ORD': 12832, 'PHL': 7063, 'OSL': 5337, 'TXL': 6747, 'DUS': 8139, 'SLC': 4159, 'YYC': 3649, 'MRS': 3531, 'PTY': 2817, 'ATL': 16317, 'MSP': 6069, 'DEL': 5092, 'CLT': 5531, 'AMM': 4133, 'STN': 2812, 'ACE': 3558, 'IAD': 6565, 'LHR': 17997, 'CGO': 6503, 'SYX': 4591, 'KIX': 5009, 'TAO': 6295, 'GVA': 6013, 'TLV': 5531, 'MXP': 6888, 'CGK': 4182, 'CAI': 4389, 'CUN': 5608, 'FOC': 5450, 'KWE': 5263, 'NBO': 2896, 'AMS': 12314, 'BWI': 4126, 'MSY': 5404, 'ATH': 5758, 'ARN': 6307, 'ORY': 3625, 'TNA': 5500, 'MIA': 8090, 'MDW': 3347, 'CSX': 6060, 'CMN': 3722, 'VCE': 4806, 'SJU': 2852, 'GRU': 3734, 'DCA': 4095, 'BNE': 2556, 'TSN': 5168, 'HAM': 5990, 'FAO': 3427, 'MLA': 4062, 'RIX': 3864, 'AYT': 4357, 'LYS': 3850, 'NCE': 4366, 'LGA': 4005, 'LIM': 2743, 'HEL': 5468, 'PHX': 6252, 'MCT': 3427, 'HAK': 4574, 'STL': 4121, 'KZN': 927, 'AER': 5479, 'HRB': 3919, 'CGN': 4206, 'OTP': 3809, 'SAW': 3687, 'SYD': 4387, 'TYN': 4034, 'DLC': 4924}

# %% [markdown]
# ## (H).  Display Your Result
#
# Use your favorite approach to show the results in sorted format, descending by PageRank score. The entries at the top should be the entries with highest PageRank. What are the most important elements in the data set?
#
# You may show either the complete list or just the top 10.
#
# Check your code by comparing your top 10 to mine. Because we are using a randomized algorithm, your results will not agree exactly with mine, but they should be relatively close. If your top 10 list is very different, then you might want to revisit your previous solutions.
#
# For Hamilton, my top 10 were:
#
# ```
# [('hamilton', 166062),
#  ('burr', 99180),
#  ('washington', 92246),
#  ('jefferson', 72450),
#  ('eliza', 51485),
#  ('angelica', 48042),
#  ('madison', 37421),
#  ('lafayette', 34297),
#  ('lee', 33678),
#  ('jAdams', 31121)]
# ```
#
# For the flights data, my top 10 were:
#
# ```
# [('LHR', 18043), # London Heathrow
#  ('ATL', 16370), # Atlanta
#  ('JFK', 14795), # New York JFK
#  ('FRA', 14156), # Frankfurt
#  ('CDG', 14073), # Charles de Gaulle (Paris)
#  ('LAX', 13199), # Los Angeles
#  ('ORD', 12915), # Chicago O'Hare
#  ('PEK', 12525), # Beijing
#  ('AMS', 12410), # Amsterdam Schiphol
#  ('PVG', 11517)] # Shanghai
# ```
# #### Your solution

# %%
newD={} #Creating a new dictionary to sort the old dictionary 
while len(newD) < len(D):
    smallest_airport=" " #initialize the smallest airport to a blank space(as a placeholder) and
    airport_size=0    #initialize airport size to 0
    for i in D.keys():
        if(((airport_size < D[i]) or (smallest_airport == "")) and (i not in newD)):
                smallest_airport=i  #if there is a new smallest airport, change the value 
                                    #of the smallest airport, and the airport size
                airport_size=D[i]
        else:   #if the new minimum is not reached, just keep iterating 
            pass
    newD[smallest_airport]=airport_size #add the new smallest airport into the new dictionary 
print(newD)
# Out:
# {'LHR': 17997, 'ATL': 16317, 'JFK': 14786, 'CDG': 14374, 'FRA': 14217, 'LAX': 13126, 'ORD': 12832, 'PEK': 12448, 'AMS': 12314, 'PVG': 11255, 'MUC': 10958, 'HKG': 10927, 'FCO': 10722, 'BCN': 10625, 'ICN': 10368, 'SIN': 10254, 'MAD': 9841, 'BKK': 9771, 'NRT': 9441, 'DFW': 9174, 'DXB': 9139, 'YYZ': 9049, 'CAN': 9022, 'VIE': 8940, 'BRU': 8708, 'CTU': 8640, 'ZRH': 8602, 'SFO': 8547, 'HGH': 8447, 'TPE': 8377, 'MAN': 8316, 'XIY': 8278, 'LGW': 8187, 'DUS': 8139, 'MIA': 8090, 'EWR': 7934, 'AUH': 7808, 'CPH': 7777, 'KMG': 7722, 'XMN': 7656, 'CKG': 7459, 'IST': 7347, 'DEN': 7194, 'PHL': 7063, 'MXP': 6888, 'LIS': 6878, 'TXL': 6747, 'SZX': 6705, 'IAD': 6565, 'BOS': 6558, 'SEA': 6545, 'LAS': 6507, 'CGO': 6503, 'KUL': 6496, 'PRG': 6436, 'ARN': 6307, 'DOH': 6296, 'TAO': 6295, 'WUH': 6269, 'PMI': 6267, 'DTW': 6262, 'PHX': 6252, 'MCO': 6233, 'DUB': 6091, 'NKG': 6091, 'MSP': 6069, 'SHA': 6064, 'CSX': 6060, 'IAH': 6041, 'GVA': 6013, 'YUL': 6004, 'HAM': 5990, 'ATH': 5758, 'AGP': 5706, 'CUN': 5608, 'CLT': 5531, 'TLV': 5531, 'TNA': 5500, 'AER': 5479, 'HEL': 5468, 'FOC': 5450, 'MSY': 5404, 'OSL': 5337, 'KWE': 5263, 'TSN': 5168, 'SVO': 5155, 'DEL': 5092, 'JED': 5034, 'MEX': 5024, 'BOM': 5010, 'KIX': 5009, 'DME': 4971, 'FLL': 4965, 'DLC': 4924, 'VCE': 4806, 'YVR': 4758, 'NNG': 4746, 'TFS': 4678, 'SAN': 4626, 'KWL': 4608, 'SYX': 4591, 'HAK': 4574, 'LPA': 4506, 'SHE': 4504, 'CTA': 4502, 'WAW': 4444, 'CAI': 4389, 'SYD': 4387, 'NCE': 4366, 'STR': 4357, 'AYT': 4357, 'CGN': 4206, 'HER': 4203, 'CGK': 4182, 'TPA': 4161, 'SLC': 4159, 'AMM': 4133, 'BWI': 4126, 'MNL': 4125, 'STL': 4121, 'EDI': 4111, 'HNL': 4104, 'DCA': 4095, 'MLA': 4062, 'BHX': 4038, 'RUH': 4037, 'TYN': 4034, 'LGA': 4005, 'LED': 3981, 'ALC': 3971, 'HRB': 3919, 'PDX': 3875, 'RIX': 3864, 'LYS': 3850, 'OTP': 3809, 'KBP': 3747, 'GRU': 3734, 'CMN': 3722, 'SAW': 3687, 'KWI': 3681, 'URC': 3657, 'YYC': 3649, 'ORY': 3625, 'CMB': 3623, 'ACE': 3558, 'MRS': 3531, 'HND': 3429, 'FAO': 3427, 'MCT': 3427, 'SGN': 3416, 'MDW': 3347, 'MEL': 3345, 'JNB': 3265, 'LTN': 3144, 'BOG': 3090, 'ADD': 2964, 'MAA': 2952, 'NBO': 2896, 'SJU': 2852, 'PTY': 2817, 'STN': 2812, 'LIM': 2743, 'BNE': 2556, 'KZN': 927}

# %% [markdown]
# ## (I). Submit!
#
# Check that your code is appropriately documented (comments and docstrings), and turn it in.
